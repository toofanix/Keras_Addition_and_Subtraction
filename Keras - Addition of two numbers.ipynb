# %% [markdown]
# Inspired from
# https://github.com/fchollet/keras/blob/master/examples/addition_rnn.py
#
# Here I am trying to achive sequence to sequence learning. In this case we are trying to enter 2 numbers as text and add them together but with machine learning.

# %%
from keras.models import Sequential
from keras.engine.training import slice_X
from keras.layers import Activation,TimeDistributed,Dense,RepeatVector,recurrent
import numpy as np
from six.moves import range
from keras.utils.visualize_util import plot

# %%
class CharacterTable(object):
    def __init__(self,chars):
        self.chars = sorted(set(chars))
        self.char_indices = dict((c,i) for i,c in enumerate(self.chars))
        self.indices_char = dict((i,c) for i,c in enumerate(self.chars))
        
    def enconde(self,C,num_rows):
        X = np.zeros((num_rows,len(self.chars)))
        for i,c in enumerate(C):
            X[i,self.char_indices[c]] = 1
        return X
    
    def decode(self,X,calc_argmax=True):
        if calc_argmax:
            X = X.argmax(axis=-1)
        return ''.join(self.indices_char[x] for x in X)
        
class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %%
TRAINING_SIZE = 50000
DIGITS = 3
INVERT = True
MAXLEN = DIGITS + 1 + DIGITS

chars = '0123456789+ '
ctable = CharacterTable(chars)

# %%
questions = []
expected = []
seen = set()
print ("Generating...")
count = 1
while len(questions) < TRAINING_SIZE:
    if count % 10000 == 0:
        print (count)
        
    f = lambda:int(''.join(np.random.choice(list('0123456789'))
                          for i in range(np.random.randint(1,DIGITS+1))))
    a , b = f(), f()
    
    key = tuple(sorted((a,b)))
    if key in seen:
        continue
    seen.add(key)
    
    q = '{}+{}'.format(a,b)
    query = q+' '*(MAXLEN-len(q))
    ans = str(a+b)
    ans +=' '*(DIGITS+1-len(ans))
    
    if INVERT:
        query = query[::-1]
    questions.append(query)
    expected.append(ans)
    count += 1
    
    
print ("Total addition questions = {}".format(len(questions)))
# Out:
# Generating...
# 1000
# 1000
# 2000
# 3000
# 3000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 8000
# 9000
# 9000
# 9000
# 10000
# 10000
# 11000
# 11000
# 12000
# 12000
# 13000
# 14000
# 14000
# 15000
# 15000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 20000
# 21000
# 22000
# 23000
# 23000
# 23000
# 24000
# 25000
# 25000
# 25000
# 26000
# 26000
# 26000
# 26000
# 26000
# 26000
# 26000
# 27000
# 27000
# 28000
# 28000
# 29000
# 29000
# 30000
# 31000
# 31000
# 32000
# 32000
# 32000
# 32000
# 32000
# 32000
# 32000
# 32000
# 32000
# 33000
# 33000
# 33000
# 34000
# 34000
# 34000
# 34000
# 35000
# 35000
# 35000
# 36000
# 37000
# 38000
# 38000
# 38000
# 38000
# 38000
# 39000
# 39000
# 39000
# 39000
# 40000
# 41000
# 42000
# 42000
# 42000
# 43000
# 43000
# 43000
# 44000
# 44000
# 44000
# 44000
# 44000
# 45000
# 45000
# 46000
# 46000
# 46000
# 47000
# 47000
# 47000
# 48000
# 48000
# 49000
# 49000
# 50000
# 50000
# 50000
# 50000
# Total addition questions = 50000

# %%
# Remember the questions are inverted
print ('Few examples of input and output :')
for i in range(6):
    print ("{} = {}".format(questions[i],expected[i]))
# Out:
# Few examples of input and output :
#  827+03 = 758
#   01+53 = 45
#    0+28 = 82
#    0+97 = 79
#  091+96 = 259
#   6+967 = 775

# %%
print ('Vecotrization...')
X = np.zeros((len(questions),MAXLEN,len(chars)),dtype=np.bool)
y = np.zeros((len(questions),DIGITS+1,len(chars)),dtype=np.bool)
for i, sentence in enumerate(questions):
    X[i] = ctable.enconde(sentence,MAXLEN)

for i, sentence in enumerate(expected):
    y[i] = ctable.enconde(sentence,DIGITS+1)
# Out:
# Vecotrization...

# %%
#Randomizing the input and output
indices = np.arange(len(y))
np.random.shuffle(indices)
X = X[indices]
y = y[indices]

# %%
# Separating 10% of the data for test and 90% data for training.
split_at = len(X) - len(X)//10
(X_train, X_test) = (slice_X(X,0,split_at),slice_X(X,split_at))
(y_train, y_test) = (y[:split_at],y[split_at:])

print ("Training Data :")
print (X_train.shape)
print (y_train.shape)

print ("Test Data :")
print (X_test.shape)
print (y_test.shape)
# Out:
# Training Data :
# (45000, 7, 12)
# (45000, 4, 12)
# Test Data :
# (5000, 7, 12)
# (5000, 4, 12)

# %%
RNN = recurrent.LSTM
HIDDEN_SIZE = 128
BATCH_SIZE = 128
LAYERS = 1

# %%
model = Sequential()
model.add(RNN(HIDDEN_SIZE,input_shape=(MAXLEN,len(chars))))
model.add(RepeatVector(DIGITS+1))

for _ in range(LAYERS):
    model.add(RNN(HIDDEN_SIZE,return_sequences=True))
    
model.add(TimeDistributed(Dense(len(chars))))
model.add(Activation('softmax'))
model.compile(loss = 'categorical_crossentropy',
             optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lstm_7 (LSTM)                    (None, 128)           72192       lstm_input_4[0][0]
# ____________________________________________________________________________________________________
# repeatvector_4 (RepeatVector)    (None, 4, 128)        0           lstm_7[0][0]
# ____________________________________________________________________________________________________
# lstm_8 (LSTM)                    (None, 4, 128)        131584      repeatvector_4[0][0]
# ____________________________________________________________________________________________________
# timedistributed_4 (TimeDistribut (None, 4, 12)         1548        lstm_8[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 4, 12)         0           timedistributed_4[0][0]
# ====================================================================================================
# Total params: 205,324
# Trainable params: 205,324
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
for iteration in range(1,100):
    print ()
    print ('-'*50)
    print ('Iteration - ',iteration)
    model.fit(X_train,y_train,batch_size=BATCH_SIZE,nb_epoch=1,validation_data=(X_test,y_test))
    
    for i in range(2):
        ind = np.random.randint(0,len(X_test))
        rowX, rowy = X_test[np.array([ind])], y_test[np.array([ind])]
        preds = model.predict_classes(rowX,verbose=0)
        q = ctable.decode(rowX[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0],calc_argmax=False)
        
        print (" Q ", q[::-1] if INVERT else q)
        print (" T ", correct)
        if correct == guess:
            print (colors.ok +'☑' + colors.close,end = " ")
        else:
            print (colors.fail + '☒' + colors.close,end = " ")
            
        print (guess)
        print ('---')
# Out:
# --------------------------------------------------
# Iteration -  1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#   256/45000 [..............................] - ETA: 45s - loss: 0.1093 - acc: 0.9785
#  Q  330+641
#  T  971
# ☒ 961
# ---
#  Q  44+63
#  T  107
# ☑ 107
# ---
#
# --------------------------------------------------
# Iteration -  2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 44800/45000 [============================>.] - ETA: 0s - loss: 0.0819 - acc: 0.9859
#  Q  368+430
#  T  798
# ☒ 898
# ---
#  Q  22+906
#  T  928
# ☑ 928
# ---
#
# --------------------------------------------------
# Iteration -  3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 24704/45000 [===============>..............] - ETA: 18s - loss: 0.0651 - acc: 0.9906
#  Q  411+6
#  T  417
# ☑ 417
# ---
#  Q  77+1
#  T  78
# ☑ 78
# ---
#
# --------------------------------------------------
# Iteration -  4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 36224/45000 [=======================>......] - ETA: 7s - loss: 0.0723 - acc: 0.9843
#  Q  461+87
#  T  548
# ☑ 548
# ---
#  Q  5+253
#  T  258
# ☑ 258
# ---
#
# --------------------------------------------------
# Iteration -  5
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 38s - loss: 0.0444 - acc: 0.9936 - val_loss: 0.0478 - val_acc: 0.9914
#  Q  262+348
#  T  610
# ☑ 610
# ---
#  Q  566+648
#  T  1214
# ☑ 1214
# ---
#
# --------------------------------------------------
# Iteration -  6
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 45s - loss: 0.0382 - acc: 0.9945 - val_loss: 0.0538 - val_acc: 0.9870
#  Q  164+625
#  T  789
# ☑ 789
# ---
#  Q  1+865
#  T  866
# ☑ 866
# ---
#
# --------------------------------------------------
# Iteration -  7
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  - ETA: 2s - loss: 0.0415 - acc: 0.9921
#  Q  541+756
#  T  1297
# ☑ 1297
# ---
#  Q  89+23
#  T  112
# ☑ 112
# ---
#
# --------------------------------------------------
# Iteration -  8
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  - ETA: 24s - loss: 0.0261 - acc: 0.9970
#  Q  90+106
#  T  196
# ☑ 196
# ---
#  Q  92+835
#  T  927
# ☑ 927
# ---
#
# --------------------------------------------------
# Iteration -  9
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  - ETA: 17s - loss: 0.0454 - acc: 0.9892
#  Q  968+48
#  T  1016
# ☑ 1016
# ---
#  Q  273+15
#  T  288
# ☑ 288
# ---
#
# --------------------------------------------------
# Iteration -  10
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 39936/45000 [=========================>....] - ETA: 4s - loss: 0.0184 - acc: 0.9982
#  Q  30+216
#  T  246
# ☑ 246
# ---
#  Q  78+587
#  T  665
# ☑ 665
# ---
#
# --------------------------------------------------
# Iteration -  11
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  8320/45000 [====>.........................] - ETA: 27s - loss: 0.0148 - acc: 0.9990
#  Q  239+93
#  T  332
# ☑ 332
# ---
#  Q  84+305
#  T  389
# ☑ 389
# ---
#
# --------------------------------------------------
# Iteration -  12
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 42752/45000 [===========================>..] - ETA: 1s - loss: 0.0496 - acc: 0.9859
#  Q  115+0
#  T  115
# ☑ 115
# ---
#  Q  501+22
#  T  523
# ☑ 523
# ---
#
# --------------------------------------------------
# Iteration -  13
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 13184/45000 [=======>......................] - ETA: 24s - loss: 0.0128 - acc: 0.9992
#  Q  671+894
#  T  1565
# ☑ 1565
# ---
#  Q  22+954
#  T  976
# ☑ 976
# ---
#
# --------------------------------------------------
# Iteration -  14
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  - ETA: 11s - loss: 0.0103 - acc: 0.9994
#  Q  944+94
#  T  1038
# ☑ 1038
# ---
#  Q  197+591
#  T  788
# ☑ 788
# ---
#
# --------------------------------------------------
# Iteration -  15
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  - ETA: 27s - loss: 0.1472 - acc: 0.9550
#  Q  0+681
#  T  681
# ☑ 681
# ---
#  Q  74+46
#  T  120
# ☑ 120
# ---
#
# --------------------------------------------------
# Iteration -  16
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 41s - loss: 0.0088 - acc: 0.9996 - val_loss: 0.0125 - val_acc: 0.9982
#  Q  24+928
#  T  952
# ☑ 952
# ---
#  Q  67+600
#  T  667
# ☑ 667
# ---
#
# --------------------------------------------------
# Iteration -  17
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 42s - loss: 0.0077 - acc: 0.9996 - val_loss: 0.0109 - val_acc: 0.9985
#  Q  65+774
#  T  839
# ☑ 839
# ---
#  Q  5+920
#  T  925
# ☑ 925
# ---
#
# --------------------------------------------------
# Iteration -  18
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  - ETA: 0s - loss: 0.0295 - acc: 0.9923
#  Q  412+5
#  T  417
# ☑ 417
# ---
#  Q  4+765
#  T  769
# ☑ 769
# ---
#
# --------------------------------------------------
# Iteration -  19
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 18432/45000 [===========>..................] - ETA: 20s - loss: 0.0421 - acc: 0.9876
#  Q  85+363
#  T  448
# ☑ 448
# ---
#  Q  789+13
#  T  802
# ☑ 802
# ---
#
# --------------------------------------------------
# Iteration -  20
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 40s - loss: 0.0062 - acc: 0.9997 - val_loss: 0.0103 - val_acc: 0.9984
#  Q  75+70
#  T  145
# ☑ 145
# ---
#  Q  48+156
#  T  204
# ☑ 204
# ---
#
# --------------------------------------------------
# Iteration -  21
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 22400/45000 [=============>................] - ETA: 18s - loss: 0.0054 - acc: 0.9998
#  Q  771+658
#  T  1429
# ☑ 1429
# ---
#  Q  448+248
#  T  696
# ☑ 696
# ---
#
# --------------------------------------------------
# Iteration -  22
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  - ETA: 1s - loss: 0.0116 - acc: 0.9979
#  Q  10+493
#  T  503
# ☑ 503
# ---
#  Q  562+98
#  T  660
# ☑ 660
# ---
#
# --------------------------------------------------
# Iteration -  23
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 44928/45000 [============================>.] - ETA: 0s - loss: 0.0387 - acc: 0.9887
#  Q  380+538
#  T  918
# ☑ 918
# ---
#  Q  100+949
#  T  1049
# ☑ 1049
# ---
#
# --------------------------------------------------
# Iteration -  24
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 38912/45000 [========================>.....] - ETA: 4s - loss: 0.0052 - acc: 0.9998
#  Q  416+795
#  T  1211
# ☑ 1211
# ---
#  Q  62+86
#  T  148
# ☑ 148
# ---
#
# --------------------------------------------------
# Iteration -  25
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  - ETA: 24s - loss: 0.0040 - acc: 0.9999
#  Q  11+301
#  T  312
# ☑ 312
# ---
#  Q  147+82
#  T  229
# ☑ 229
# ---
#
# --------------------------------------------------
# Iteration -  26
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  - ETA: 25s - loss: 0.0040 - acc: 0.9998
#  Q  743+397
#  T  1140
# ☑ 1140
# ---
#  Q  82+270
#  T  352
# ☑ 352
# ---
#
# --------------------------------------------------
# Iteration -  27
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  - ETA: 2s - loss: 0.0416 - acc: 0.9871
#  Q  160+56
#  T  216
# ☑ 216
# ---
#  Q  932+73
#  T  1005
# ☑ 1005
# ---
#
# --------------------------------------------------
# Iteration -  28
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  - ETA: 31s - loss: 0.0229 - acc: 0.9935
#  Q  20+855
#  T  875
# ☑ 875
# ---
#  Q  2+758
#  T  760
# ☑ 760
# ---
#
# --------------------------------------------------
# Iteration -  29
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 41s - loss: 0.0032 - acc: 0.9999 - val_loss: 0.0062 - val_acc: 0.9989
#  Q  4+155
#  T  159
# ☑ 159
# ---
#  Q  54+94
#  T  148
# ☑ 148
# ---
#
# --------------------------------------------------
# Iteration -  30
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 34688/45000 [======================>.......] - ETA: 8s - loss: 0.0027 - acc: 0.9999
#  Q  45+174
#  T  219
# ☑ 219
# ---
#  Q  285+717
#  T  1002
# ☑ 1002
# ---
#
# --------------------------------------------------
# Iteration -  31
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 39552/45000 [=========================>....] - ETA: 4s - loss: 0.0027 - acc: 0.9998
#  Q  58+937
#  T  995
# ☑ 995
# ---
#  Q  614+262
#  T  876
# ☑ 876
# ---
#
# --------------------------------------------------
# Iteration -  32
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 38400/45000 [========================>.....] - ETA: 5s - loss: 0.0469 - acc: 0.9852
#  Q  331+213
#  T  544
# ☑ 544
# ---
#  Q  3+195
#  T  198
# ☑ 198
# ---
#
# --------------------------------------------------
# Iteration -  33
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  7680/45000 [====>.........................] - ETA: 28s - loss: 0.0142 - acc: 0.9964
#  Q  9+930
#  T  939
# ☑ 939
# ---
#  Q  77+96
#  T  173
# ☑ 173
# ---
#
# --------------------------------------------------
# Iteration -  34
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
#  6528/45000 [===>..........................] - ETA: 29s - loss: 0.0028 - acc: 1.0000

# %%
plot(model,to_file='model.png',show_shapes=True)
